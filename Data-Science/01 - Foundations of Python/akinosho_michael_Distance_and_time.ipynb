# %% [markdown]
# # Starter Code
#
# # Exploring NumPy Arrays: Distance and Time

# %% [markdown]
# 1) Import the numpy library

# %%
import numpy as np

# %% [markdown]
# 2) Create a numpy array called "distance" that includes the following distances (in meters): 100, 200, 400, 800, 1500, 3000, 5000, 10000

# %%
distance_array = np.array([100, 200, 400, 800, 1500, 3000, 5000, 10000])
print(distance_array)
# Out:
# [  100   200   400   800  1500  3000  5000 10000]

# %% [markdown]
# 3) Use the min() and max() functions to find the minimum and maximum distances

# %%
print('Value of minimum distance: ',distance_array.min())
print('Value of maximum distance: ',distance_array.max())
# Out:
# Value of minimum distance:  100
# Value of maximum distance:  10000

# %% [markdown]
# 4) To find the average distance, use the np.mean() function

# %%
print('Mean or average of distances: ', distance_array.mean())
# Out:
# Mean or average of distances:  2625.0

# %% [markdown]
# 5) use the sum() function to find the total distance

# %%
print('Sum of all distances: ', distance_array.sum())
# Out:
# Sum of all distances:  21000

# %% [markdown]
# 6) Another valuable function is the cumsum() function which outputs the cumulative sum...notice the output will be 100, 300, 700 as it adds each new distance

# %%
print('Cumulative sum of all distances: ',distance_array.cumsum())
# Out:
# Cumulative sum of all distances:  [  100   300   700  1500  3000  6000 11000 21000]

# %% [markdown]
# 7) To round all of the values in an array, use np.round()

# %%
#I predict this might turn the items into float, just guessing
print('Each array item rounded: ', distance_array.round(-3))
# Out:
# Each array item rounded:  [    0     0     0  1000  2000  3000  5000 10000]

# %% [markdown]
# 8) Create a numpy array called time that includes the following times (in seconds):  10.62, 21.34, 48.25, 113.43, 233.96, 506.53, 866.17, 1757.45

# %%
time_second_array = np.array([10.62, 21.34, 48.25, 113.43, 233.96, 506.53, 866.17, 1757.45])
print('Each array item; ',time_second_array)
# Out:
# Each array item;  [  10.62   21.34   48.25  113.43  233.96  506.53  866.17 1757.45]

# %% [markdown]
# 9) the values in your time array correspond to olympic records for running the corresponding distances.  Perform the calculation needed to find the speed (in m/s) for each record distance

# %%
meters_second_speed_array = (distance_array/time_second_array).round(10)
print('Speed in meters per second: ', meters_second_speed_array)
# Out:
# Speed in meters per second:  [9.41619586 9.37207123 8.29015544 7.0528079  6.41135237 5.92265019
#  5.77253888 5.69006231]

# %% [markdown]
# 10) One common problem data scientists run into is that we are given information in units that are not consistent.
# For example, we might want to compare data that is given in meters per second to data that is given in miles per hour. A cheetah is the fastest land animal which can reach speeds of 75.0 miles per hour.
# In order to compare our olympians to a cheetah, we need to be able to convert from one unit to another.
# Perform calculations to convert the olympic record speeds from meters/second into miles per hour.  Note: 1 meter = 0.00062 miles
# How do our olympians compare to the cheetah?

# %%
print('Speed in meters per second: ', meters_second_speed_array.round(4))
#Convert factor from 1 m/s to miles/hour is 2.23694
factor = 2.23694
miles_hour_speed_array = meters_second_speed_array*factor
print('Speed in miles per hour: ', miles_hour_speed_array.round(2))
# Out:
# Speed in meters per second:  [9.4162 9.3721 8.2902 7.0528 6.4114 5.9227 5.7725 5.6901]
# Speed in miles per hour:  [21.06 20.96 18.54 15.78 14.34 13.25 12.91 12.73]

# %%
print('Array to see if any athlete is faster than a cheetah: ', 75 < miles_hour_speed_array)
# Out:
# Array to see if any athlete is faster than a cheetah:  [False False False False False False False False]
