# %%
x = [ [5,2,3], [10,8,9] ] 
students = [
     {'first_name':  'Michael', 'last_name' : 'Jordan'},
     {'first_name' : 'John', 'last_name' : 'Rosales'}
]
sports_directory = {
    'basketball' : ['Kobe', 'Jordan', 'James', 'Curry'],
    'soccer' : ['Messi', 'Ronaldo', 'Rooney']
}
z = [ {'x': 10, 'y': 20} ]

x[1][0] = 15
print(x)

sports_directory['basketball'][1] = 'Bryant'
sports_directory['soccer'][0] = "Andres"
print(sports_directory)

z[0]['y'] = 30
print(z)
# Out:
# [[5, 2, 3], [15, 8, 9]]
# {'basketball': ['Kobe', 'Bryant', 'James', 'Curry'], 'soccer': ['Andres', 'Ronaldo', 'Rooney']}
# [{'x': 10, 'y': 30}]

# %%
students = [
         {'first_name':  'Michael', 'last_name' : 'Jordan'},
         {'first_name' : 'John', 'last_name' : 'Rosales'},
         {'first_name' : 'Mark', 'last_name' : 'Guillen'},
         {'first_name' : 'KB', 'last_name' : 'Tonel'}
    ]
#iterateDictionary(students) 
# should output: (it's okay if each key-value pair ends up on 2 separate lines;
# bonus to get them to appear exactly as below!)
#first_name - Michael, last_name - Jordan
#first_name - John, last_name - Rosales
#first_name - Mark, last_name - Guillen
#first_name - KB, last_name - Tonel

def iterateDictionary(students):
    for i in students:
        x, y = i.items()
        print(f"{x[0]} - {x[1]}, {y[0]} - {y[1]}")

iterateDictionary(students)
# Out:
# first_name - Michael, last_name - Jordan
# first_name - John, last_name - Rosales
# first_name - Mark, last_name - Guillen
# first_name - KB, last_name - Tonel

# %%
def iterateDictionary2(key_name, students):
    for i in students:
        x, y = i.items()
        if x[0] == key_name:
            print(x[1])
        elif y[0] == key_name:
            print(y[1])
    print('\n')


key_name = 'first_name'
iterateDictionary2(key_name, students)

key_name = 'last_name'
iterateDictionary2(key_name, students)
# Out:
# Michael
# John
# Mark
# KB
#
#
# Jordan
# Rosales
# Guillen
# Tonel

# %%
def printInfo(some_dict):
    for i in some_dict.items():
        print(f"{len(i[1])} {i[0].upper()}")
        for x in i[1]:
            print(x)
        print('\n')


dojo = {
   'locations': ['San Jose', 'Seattle', 'Dallas', 'Chicago', 'Tulsa', 'DC', 'Burbank'],
   'instructors': ['Michael', 'Amy', 'Eduardo', 'Josh', 'Graham', 'Patrick', 'Minh', 'Devon']
}
printInfo(dojo)
# Out:
# 7 LOCATIONS
# San Jose
# Seattle
# Dallas
# Chicago
# Tulsa
# DC
# Burbank
#
#
# 8 INSTRUCTORS
# Michael
# Amy
# Eduardo
# Josh
# Graham
# Patrick
# Minh
# Devon
