# %%
import random
def randInt(min=0   , max=100   ):
    if min > max:
        return (f"Unable to generate random number, max of {max} is lesser than min of {min}")
    num = random.random() * (max-min) + min
    return round(num)

# should print a random integer between 0 to 100
print(randInt())

# should print a random integer between 0 to 50
print(randInt(max=50))

# should print a random integer between 50 to 100
print(randInt(min=50))

# should print a random integer between 50 and 500
print(randInt(min=50, max=500))

# should print a random integer between 50 and 500
print(randInt(min=-2,max=-5))
# Out:
# 39
# 18
# 79
# 355
# Unable to generate random number, max of -5 is lesser than min of -2
