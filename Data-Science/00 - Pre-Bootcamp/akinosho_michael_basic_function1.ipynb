# %%
#1
#My Prediction: 5
def a():
    return 5
print(a())
# Out:
# 5

# %%
#2
#My Prediction: 10
def a():
    return 5
print(a()+a())
# Out:
# 10

# %%
#3
#My Prediction: 5
def a():
    return 5
    return 10
print(a())
# Out:
# 5

# %%
#4
#My Prediction: 5
def a():
    return 5
    print(10)
print(a())
# Out:
# 5

# %%
#5
#My Prediction: 5
#print(x) does not print anything
def a():
    print(5)
x = a()
print(x)
# Out:
# 5
# None

# %%
#6
#My Prediction: 8

#6
def a(b,c):
    print(b+c)
print(a(1,2) + a(2,3))
# Out:
# 3
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-bc5347527909> in <module>()
#       5 def a(b,c):
#       6     print(b+c)
# ----> 7 print(a(1,2) + a(2,3))
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'NoneType'

# %%
#7
#My Prediciton: '25'

def a(b,c):
    return str(b) + str(c)
print(a(2,5))
# Out:
# 25

# %%
#8
#My Prediction: 100
#               10
def a():
    b = 100
    print(b)
    if b < 10:
        return 5
    else:
        return 10
    return 7
print(a())
# Out:
# 100
# 10

# %%
#9
#My Prediction: 7
#                14
#                21
def a(b,c):
    if b<c:
        return 7
    else:
        return 14
    return 3
print(a(2,3))
print(a(5,3))
print(a(2,3) + a(5,3))
# Out:
# 7
# 14
# 21

# %%
#10
#My Prediction: 8

def a(b,c):
    return b+c
    return 10
print(a(3,5))
# Out:
# 8

# %%
#11
#My Predicition: 500
#                500
#                300
#                500
b = 500
print(b)
def a():
    b = 300
    print(b)
print(b)
a()
print(b)
# Out:
# 500
# 500
# 300
# 500

# %%
#12
#My Prediction: 500
#               500
#               300
#               500
b = 500
print(b)
def a():
    b = 300
    print(b)
    return b
print(b)
a()
print(b)
# Out:
# 500
# 500
# 300
# 500

# %%
#13
#My Prediction: 500
#               500
#               300
#               300
b = 500
print(b)
def a():
    b = 300
    print(b)
    return b
print(b)
b=a()
print(b)
# Out:
# 500
# 500
# 300
# 300

# %%
#14
#My Prediction: 1
#               3
#               2
def a():
    print(1)
    b()
    print(2)
def b():
    print(3)
a()
# Out:
# 1
# 3
# 2

# %%
#15
#My Prediction: 1
#               3
#               5
#               10
def a():
    print(1)
    x = b()
    print(x)
    return 10
def b():
    print(3)
    return 5
y = a()
print(y)
# Out:
# 1
# 3
# 5
# 10
