# %%
# Mounting Google Drive
# Adding error handling when running Colab notebook locally
# Adding cell notebook when ran locally on a machine with 32 GB of RAM and i9 Processor
# If running, run as standard Colab file please provide path to file in the try block
try:
    from google.colab import drive
    drive.mount('/content/drive')
    filepathname = ""
except ModuleNotFoundError:
    filepath = 'C:\\Users\\micha\\Documents\\GitHub\\codingdojo\\data-science-assignments\\12 - SQL\\'
    school_file = filepath + 'School_Details.csv'
    facility_file = filepath + 'School_Facility_Details.csv'

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# load school data
school = pd.read_csv(school_file)
school.head()

# %%
# load facility data
facility = pd.read_csv(facility_file)
facility.head()

# %%
# Create sqlite engine
engine = create_engine('sqlite:///school.db', echo = True)
# Create connection to engine
conn = engine.connect()

# %%
# Add the school dataframe as a table in sqlite
sqlite_table = "school_details"
school.to_sql(sqlite_table, conn, if_exists = 'replace')

# %%
# Add the facility dataframe as a table in sqlite
sqlite_table = "school_facility_details"
facility.to_sql(sqlite_table, conn, if_exists = 'replace')

# %%
def returndata(sql_statement, num_rows=5):
    df = pd.read_sql_query(sql_statement, engine)
    print(df.head(11))
    print("\n")

# %%
# Write your SQL query in this string
sql1 = """
SELECT school_details.EstablishmentName, school_details.SchoolLevel, school_details.Website 
FROM school_details;
"""
returndata(sql1)

sql2 = """
SELECT school_details.EstablishmentName, school_details.[DistrictHQDistance (in Km)] 
FROM school_details
WHERE school_details.[DistrictHQDistance (in Km)] > 100;
"""
returndata(sql2)

sql3 = """
SELECT school_details.EstablishmentName, school_details.[DistrictHQDistance (in Km)] 
FROM school_details
WHERE school_details.[SchoolLevel] = "JHS";
"""
returndata(sql3)

sql4 = """
SELECT school_details.EstablishmentName, school_details.[DistrictHQDistance (in Km)] 
FROM school_details
WHERE school_details.[EstablishmentName] LIKE "%JUNIOR HIGH%";
"""
returndata(sql4)

sql5 = """
SELECT school_details.EstablishmentName, school_details.[DistrictHQDistance (in Km)] 
FROM school_details
WHERE school_details.[EstablishmentName] LIKE "C%"
ORDER BY school_details.[EstablishmentName]
LIMIT 10;
"""
returndata(sql5)

sql6 = """
SELECT school_details.EstablishmentName 
FROM school_details
WHERE school_details.[LocatedInRuralOrUrban] = "Urban Area"
ORDER BY school_details.[EstablishmentName] Desc;
"""
returndata(sql6)

sql7 = """
SELECT school_details.EstablishmentName AS name
FROM school_details
WHERE school_details.[LocatedInRuralOrUrban] = "Urban Area"
ORDER BY school_details.[EstablishmentName] Desc;
"""
returndata(sql7)

# %%
sql1 = """
SELECT AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
FROM school_details
"""
returndata(sql1)

sql2 = """
SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
FROM school_details
GROUP BY school_details.SchoolLevel
"""
returndata(sql2)

sql3 = """
SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
FROM school_details
GROUP BY school_details.SchoolLevel
HAVING AVG(school_details.[BACDistance (in Km)]) >= 10
"""
returndata(sql3)

sql4 = """
SELECT * 
FROM school_details LEFT JOIN school_facility_details 
ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
LIMIT 2
"""
returndata(sql4, 2)

sql5 = """
SELECT * 
FROM school_details LEFT JOIN school_facility_details 
ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
WHERE school_details.SchoolLevel = "PS"
"""
returndata(sql5)

sql6 = """
SELECT * 
FROM school_details LEFT JOIN school_facility_details 
ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
WHERE school_details.SchoolLevel = "PS"
ORDER BY school_details.EstablishmentName
"""
returndata(sql6)
# Out:
# 2022-01-03 12:55:01,013 INFO sqlalchemy.engine.Engine
# SELECT AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
# FROM school_details
#
# 2022-01-03 12:55:01,014 INFO sqlalchemy.engine.Engine [raw sql] ()
#    avg_bac_distance
# 0         12.681822
#
#
# 2022-01-03 12:55:01,019 INFO sqlalchemy.engine.Engine
# SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
# FROM school_details
# GROUP BY school_details.SchoolLevel
#
# 2022-01-03 12:55:01,019 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0        None               NaN
# 1         JHS         13.692647
# 2         LPS          5.368421
# 3          PS         12.830787
# 4          SS         12.630872
# 5         SSS         10.863095
#
#
# 2022-01-03 12:55:01,024 INFO sqlalchemy.engine.Engine
# SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
# FROM school_details
# GROUP BY school_details.SchoolLevel
# HAVING AVG(school_details.[BACDistance (in Km)]) >= 10
#
# 2022-01-03 12:55:01,025 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0         JHS         13.692647
# 1          PS         12.830787
# 2          SS         12.630872
# 3         SSS         10.863095
#
#
# 2022-01-03 12:55:01,029 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details LEFT JOIN school_facility_details
# ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
# LIMIT 2
#
# 2022-01-03 12:55:01,030 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName  ...  \
# 0    State Govt.             BUDANG         Gangtok  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok  ...
#
#                                    EstablishmentName IsLibraryAvailable  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)          Available
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL          Available
#
#   AvailableBooksCount IsFireExtgAvailable ExtinguisherCount HOIRoomAvailable  \
# 0                 100           Available                 2        Available
# 1                   0           Available                 5        Available
#
#   IsStaffRoomAvailable NoofStaffRoom IsLockerForStaffAvailable  \
# 0            Available             1             Not Available
# 1            Available             2             Not Available
#
#   IsSportsStoreRoomAvailable
# 0              Not Available
# 1                  Available
#
# [2 rows x 43 columns]
#
#
# 2022-01-03 12:55:01,042 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details LEFT JOIN school_facility_details
# ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
# WHERE school_details.SchoolLevel = "PS"
#
# 2022-01-03 12:55:01,043 INFO sqlalchemy.engine.Engine [raw sql] ()
#     index DistrictName EstablishmentCode  \
# 0       0         East             S0169
# 1       5         East             S0856
# 2       6         East             S0870
# 3       7         East             S0157
# 4       8         East             S0876
# 5       9         East             S0164
# 6      13         East             S0137
# 7      14         East             S0179
# 8      15         East             S1230
# 9      16         East             S0768
# 10     20         East             S0131
#
#                              EstablishmentName   BRCName  \
# 0         BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1             EASWARAMMA SAI GURUKOOL ACCADEMY  Duga Brc
# 2          ETERNAL ENGLISH SCHOOL, WEST PENDAM  Duga Brc
# 3         KHANI GOAN GOVERNMENT PRIMARY SCHOOL  Duga Brc
# 4          NEW GARDEN BOARDING SCHOOL (SAJONG)  Duga Brc
# 5         OKHARBOTEY GOVERNMENT PRIMARY SCHOOL  Duga Brc
# 6        SAKHU KHANI GOVERNMENT PRIMARY SCHOOL  Duga Brc
# 7   SAMSING SUNTALEY GOVERNMENT PRIMARY SCHOOL  Duga Brc
# 8          SARASWATI SHISHU VIDHYALAYA, BUDANG  Duga Brc
# 9             SAWNEY GOVERNMENT PRIMARY SCHOOL  Duga Brc
# 10      UPPER PACHAK GOVERNMENT PRIMARY SCHOOL  Duga Brc
#
#                                               CRCName SchoolLevel  \
# 0   Central Pendam Government Senior Secondary School          PS
# 1   Central Pendam Government Senior Secondary School          PS
# 2   Central Pendam Government Senior Secondary School          PS
# 3   Central Pendam Government Senior Secondary School          PS
# 4   Central Pendam Government Senior Secondary School          PS
# 5   Central Pendam Government Senior Secondary School          PS
# 6   Central Pendam Government Senior Secondary School          PS
# 7   Central Pendam Government Senior Secondary School          PS
# 8   Central Pendam Government Senior Secondary School          PS
# 9   Central Pendam Government Senior Secondary School          PS
# 10  Central Pendam Government Senior Secondary School          PS
#
#        ManagementName LocalityHabitation SubdivisionName  ...  \
# 0         State Govt.             BUDANG         Gangtok  ...
# 1   Private (Unaided)             RALUNG         Gangtok  ...
# 2   Private (Unaided)  SAKHU WEST PENDAM         Gangtok  ...
# 3         State Govt.        WEST PENDAM         Gangtok  ...
# 4   Private (Unaided)     CENTRAL PENDAM         Gangtok  ...
# 5         State Govt.        OKHARBOTTEY         Gangtok  ...
# 6         State Govt.              SAKHU         Gangtok  ...
# 7         State Govt.   SAMSING SUNTALEY         Gangtok  ...
# 8   Private (Unaided)     CENTRAL PENDAM         Gangtok  ...
# 9         State Govt.             SAWNEY         Gangtok  ...
# 10        State Govt.       UPPER PACHAK         Gangtok  ...
#
#                              EstablishmentName IsLibraryAvailable  \
# 0         BUDANG GOVERNMENT PRIMARY SCHOOL (E)          Available
# 1             EASWARAMMA SAI GURUKOOL ACCADEMY      Not Available
# 2          ETERNAL ENGLISH SCHOOL, WEST PENDAM          Available
# 3         KHANI GOAN GOVERNMENT PRIMARY SCHOOL          Available
# 4          NEW GARDEN BOARDING SCHOOL (SAJONG)      Not Available
# 5         OKHARBOTEY GOVERNMENT PRIMARY SCHOOL          Available
# 6        SAKHU KHANI GOVERNMENT PRIMARY SCHOOL          Available
# 7   SAMSING SUNTALEY GOVERNMENT PRIMARY SCHOOL          Available
# 8          SARASWATI SHISHU VIDHYALAYA, BUDANG      Not Available
# 9             SAWNEY GOVERNMENT PRIMARY SCHOOL      Not Available
# 10      UPPER PACHAK GOVERNMENT PRIMARY SCHOOL      Not Available
#
#    AvailableBooksCount IsFireExtgAvailable ExtinguisherCount HOIRoomAvailable  \
# 0                100.0           Available               2.0        Available
# 1                  0.0           Available               2.0        Available
# 2                  0.0           Available               1.0    Not Available
# 3                 60.0           Available               2.0    Not Available
# 4                  0.0       Not Available               0.0    Not Available
# 5                 20.0           Available               2.0        Available
# 6                  0.0           Available               2.0    Not Available
# 7                 25.0           Available               1.0    Not Available
# 8                  0.0       Not Available               0.0    Not Available
# 9                  0.0           Available               1.0        Available
# 10                 0.0           Available               1.0    Not Available
#
#    IsStaffRoomAvailable NoofStaffRoom IsLockerForStaffAvailable  \
# 0             Available           1.0             Not Available
# 1         Not Available           0.0             Not Available
# 2         Not Available           0.0             Not Available
# 3             Available           1.0                 Available
# 4         Not Available           0.0             Not Available
# 5             Available           1.0             Not Available
# 6         Not Available           0.0             Not Available
# 7             Available           1.0             Not Available
# 8             Available           1.0             Not Available
# 9             Available           1.0             Not Available
# 10            Available           1.0             Not Available
#
#    IsSportsStoreRoomAvailable
# 0               Not Available
# 1               Not Available
# 2               Not Available
# 3               Not Available
# 4                   Available
# 5               Not Available
# 6               Not Available
# 7               Not Available
# 8               Not Available
# 9               Not Available
# 10              Not Available
#
# [11 rows x 43 columns]
#
#
# 2022-01-03 12:55:01,067 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details LEFT JOIN school_facility_details
# ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
# WHERE school_details.SchoolLevel = "PS"
# ORDER BY school_details.EstablishmentName
#
# 2022-01-03 12:55:01,068 INFO sqlalchemy.engine.Engine [raw sql] ()
#     index DistrictName EstablishmentCode  \
# 0    1219         West             S1034
# 1      54         East             S0516
# 2     816        South             S0692
# 3    1102         West             S0374
# 4     345         East             S0178
# 5     209         East             S0108
# 6     832        South             S0415
# 7     817        South             S0646
# 8     916         West             S0529
# 9     939         West             S0557
# 10    691        South             S0682
#
#                                     EstablishmentName       BRCName  \
# 0   (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...    Yuksom Brc
# 1                 10TH MILE GOVERNMENT PRIMARY SCHOOL   Gangtok Brc
# 2                   AAPGAZI GOVERNMENT PRIMARY SCHOOL      Temi Brc
# 3                 AARUBOTEY GOVERNMENT PRIMARY SCHOOL    Soreng Brc
# 4                  AGRIGAON GOVERNMENT PRIMARY SCHOOL      Regu Brc
# 5               AHO-YANGTAM GOVERNMENT PRIMARY SCHOOL   Pakyong Brc
# 6                  AIFALTAR GOVERNMENT PRIMARY SCHOOL      Temi Brc
# 7                    AMALAY GOVERNMENT PRIMARY SCHOOL      Temi Brc
# 8                   AMBOTEY GOVERNMENT PRIMARY SCHOOL  Daramdin Brc
# 9                     ANDEN GOVERNMENT PRIMARY SCHOOL  Daramdin Brc
# 10                 ANITHANG GOVERNMENT PRIMARY SCHOOL  Ravangla Brc
#
#                                         CRCName SchoolLevel  \
# 0             Melli Government Secondary School          PS
# 1     Enchey Government Senior Secondary School          PS
# 2        Namphing Government Junior High School          PS
# 3          Chumbong Government Secondary School          PS
# 4         Dalapchen Government Secondary School          PS
# 5        Aho-Shanti Government Secondary School          PS
# 6       Temi Government Senior Secondary School          PS
# 7        Namphing Government Junior High School          PS
# 8   Daramdin Government senior Secondary School          PS
# 9   Sombaria Government Senior Secondary School          PS
# 10          Jarrong Government Secondary School          PS
#
#        ManagementName      LocalityHabitation SubdivisionName  ...  \
# 0   Private (Unaided)  RIMBI/ SINGLITAM BUSTY       Gyalshing  ...
# 1         State Govt.     10TH MILE KARPONANG         Gangtok  ...
# 2         State Govt.                 AAPGAZI          Namchi  ...
# 3         State Govt.               AARUBOTEY          Soreng  ...
# 4         State Govt.          AGRIGAON BUSTY          Rongli  ...
# 5         State Govt.             AHO-YANGTAM         Pakyong  ...
# 6         State Govt.                AIFALTAR        Ravangla  ...
# 7         State Govt.                  AMALAY          Namchi  ...
# 8         State Govt.                 AMBOTEY          Soreng  ...
# 9         State Govt.                   ANDEN          Soreng  ...
# 10        State Govt.                ANITHANG        Ravangla  ...
#
#                                     EstablishmentName IsLibraryAvailable  \
# 0   (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...      Not Available
# 1                 10TH MILE GOVERNMENT PRIMARY SCHOOL      Not Available
# 2                   AAPGAZI GOVERNMENT PRIMARY SCHOOL      Not Available
# 3                 AARUBOTEY GOVERNMENT PRIMARY SCHOOL      Not Available
# 4                  AGRIGAON GOVERNMENT PRIMARY SCHOOL          Available
# 5               AHO-YANGTAM GOVERNMENT PRIMARY SCHOOL      Not Available
# 6                  AIFALTAR GOVERNMENT PRIMARY SCHOOL      Not Available
# 7                    AMALAY GOVERNMENT PRIMARY SCHOOL      Not Available
# 8                   AMBOTEY GOVERNMENT PRIMARY SCHOOL      Not Available
# 9                     ANDEN GOVERNMENT PRIMARY SCHOOL      Not Available
# 10                 ANITHANG GOVERNMENT PRIMARY SCHOOL      Not Available
#
#    AvailableBooksCount IsFireExtgAvailable ExtinguisherCount HOIRoomAvailable  \
# 0                  0.0           Available               1.0        Available
# 1                  0.0       Not Available               0.0        Available
# 2                  0.0       Not Available               0.0    Not Available
# 3                  0.0           Available               2.0    Not Available
# 4                 60.0           Available               2.0    Not Available
# 5                  0.0           Available               2.0        Available
# 6                  0.0       Not Available               0.0        Available
# 7                  0.0           Available               2.0    Not Available
# 8                  0.0           Available               2.0        Available
# 9                  0.0           Available               2.0        Available
# 10                 0.0           Available               2.0    Not Available
#
#    IsStaffRoomAvailable NoofStaffRoom IsLockerForStaffAvailable  \
# 0         Not Available           0.0             Not Available
# 1             Available           1.0             Not Available
# 2         Not Available           0.0             Not Available
# 3         Not Available           0.0             Not Available
# 4             Available           1.0             Not Available
# 5             Available           1.0             Not Available
# 6             Available           1.0             Not Available
# 7             Available           1.0             Not Available
# 8         Not Available           0.0             Not Available
# 9             Available           1.0             Not Available
# 10        Not Available           0.0             Not Available
#
#    IsSportsStoreRoomAvailable
# 0               Not Available
# 1               Not Available
# 2               Not Available
# 3               Not Available
# 4               Not Available
# 5               Not Available
# 6               Not Available
# 7                   Available
# 8               Not Available
# 9               Not Available
# 10              Not Available
#
# [11 rows x 43 columns]
