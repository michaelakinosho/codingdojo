# %%
# Mounting Google Drive
# Adding error handling when running Colab notebook locally
# Adding cell notebook when ran locally on a machine with 32 GB of RAM and i9 Processor
# If running, run as standard Colab file please provide path to file in the try block
try:
    from google.colab import drive
    drive.mount('/content/drive')
    filepathname = ""
except ModuleNotFoundError:
    filepath = 'C:\\Users\\micha\\Documents\\GitHub\\codingdojo\\data-science-assignments\\12 - SQL\\'
    school_file = filepath + 'School_Details.csv'
    facility_file = filepath + 'School_Facility_Details.csv'

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# load school data
school = pd.read_csv(school_file)
school.head()

# %%
# load facility data
facility = pd.read_csv(facility_file)
facility.head()

# %%
# Create sqlite engine
engine = create_engine('sqlite:///school.db', echo = True)
# Create connection to engine
conn = engine.connect()

# %%
# Add the school dataframe as a table in sqlite
sqlite_table = "school_details"
school.to_sql(sqlite_table, conn, if_exists = 'replace')

# %%
# Add the facility dataframe as a table in sqlite
sqlite_table = "school_facility_details"
facility.to_sql(sqlite_table, conn, if_exists = 'replace')

# %%
def returndata(sql_statement, num_rows=5):
    df = pd.read_sql_query(sql_statement, engine)
    print(df.head(11))
    print("\n")

# %% [markdown]
# # Start of Basic SQL Exercise

# %%
# Write your SQL query in this string
sql1 = """
SELECT school_details.EstablishmentName, school_details.SchoolLevel, school_details.Website 
FROM school_details;
"""
returndata(sql1)

# %%
sql2 = """
SELECT school_details.EstablishmentName, school_details.[DistrictHQDistance (in Km)] 
FROM school_details
WHERE school_details.[DistrictHQDistance (in Km)] > 100;
"""
returndata(sql2)

# %%
sql3 = """
SELECT school_details.EstablishmentName, school_details.[DistrictHQDistance (in Km)] 
FROM school_details
WHERE school_details.[SchoolLevel] = "JHS";
"""
returndata(sql3)

# %%
sql4 = """
SELECT school_details.EstablishmentName, school_details.[DistrictHQDistance (in Km)] 
FROM school_details
WHERE school_details.[EstablishmentName] LIKE "%JUNIOR HIGH%";
"""
returndata(sql4)

# %%
sql5 = """
SELECT school_details.EstablishmentName, school_details.[DistrictHQDistance (in Km)] 
FROM school_details
WHERE school_details.[EstablishmentName] LIKE "C%"
ORDER BY school_details.[EstablishmentName]
LIMIT 10;
"""
returndata(sql5)

# %%
sql6 = """
SELECT school_details.EstablishmentName 
FROM school_details
WHERE school_details.[LocatedInRuralOrUrban] = "Urban Area"
ORDER BY school_details.[EstablishmentName] Desc;
"""
returndata(sql6)

# %%
sql7 = """
SELECT school_details.EstablishmentName AS name
FROM school_details
WHERE school_details.[LocatedInRuralOrUrban] = "Urban Area"
ORDER BY school_details.[EstablishmentName] Desc;
"""
returndata(sql7)

# %% [markdown]
# # Start of SQL Exercise

# %%
sql1 = """
SELECT AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
FROM school_details
"""
returndata(sql1)
# Out:
# 2022-01-17 07:51:40,847 INFO sqlalchemy.engine.Engine
# SELECT AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
# FROM school_details
#
# 2022-01-17 07:51:40,848 INFO sqlalchemy.engine.Engine [raw sql] ()
#    avg_bac_distance
# 0         12.681822

# %%
sql2 = """
SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
FROM school_details
GROUP BY school_details.SchoolLevel
"""
returndata(sql2)
# Out:
# 2022-01-17 07:51:42,723 INFO sqlalchemy.engine.Engine
# SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
# FROM school_details
# GROUP BY school_details.SchoolLevel
#
# 2022-01-17 07:51:42,723 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0        None               NaN
# 1         JHS         13.692647
# 2         LPS          5.368421
# 3          PS         12.830787
# 4          SS         12.630872
# 5         SSS         10.863095

# %%
sql3 = """
SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
FROM school_details
GROUP BY school_details.SchoolLevel
HAVING AVG(school_details.[BACDistance (in Km)]) >= 10
"""
returndata(sql3)
# Out:
# 2022-01-17 07:51:45,102 INFO sqlalchemy.engine.Engine
# SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
# FROM school_details
# GROUP BY school_details.SchoolLevel
# HAVING AVG(school_details.[BACDistance (in Km)]) >= 10
#
# 2022-01-17 07:51:45,103 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0         JHS         13.692647
# 1          PS         12.830787
# 2          SS         12.630872
# 3         SSS         10.863095

# %%
sql4 = """
SELECT * 
FROM school_details LEFT JOIN school_facility_details 
ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
LIMIT 2
"""
returndata(sql4, 2)
# Out:
# 2022-01-17 07:51:47,868 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details LEFT JOIN school_facility_details
# ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
# LIMIT 2
#
# 2022-01-17 07:51:47,868 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName  ...  \
# 0    State Govt.             BUDANG         Gangtok  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok  ...
#
#                                    EstablishmentName IsLibraryAvailable  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)          Available
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL          Available
#
#   AvailableBooksCount IsFireExtgAvailable ExtinguisherCount HOIRoomAvailable  \
# 0                 100           Available                 2        Available
# 1                   0           Available                 5        Available
#
#   IsStaffRoomAvailable NoofStaffRoom IsLockerForStaffAvailable  \
# 0            Available             1             Not Available
# 1            Available             2             Not Available
#
#   IsSportsStoreRoomAvailable
# 0              Not Available
# 1                  Available
#
# [2 rows x 43 columns]

# %%
sql5 = """
SELECT * 
FROM school_details LEFT JOIN school_facility_details 
ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
WHERE school_details.SchoolLevel = "PS" AND school_facility_details.[IsLibraryAvailable] = "Not Available"
"""
returndata(sql5)
# Out:
# 2022-01-17 07:51:51,353 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details LEFT JOIN school_facility_details
# ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
# WHERE school_details.SchoolLevel = "PS" AND school_facility_details.[IsLibraryAvailable] = "Not Available"
#
# 2022-01-17 07:51:51,355 INFO sqlalchemy.engine.Engine [raw sql] ()
#     index DistrictName EstablishmentCode  \
# 0       5         East             S0856
# 1       8         East             S0876
# 2      15         East             S1230
# 3      16         East             S0768
# 4      20         East             S0131
# 5      24         East             S0245
# 6      28         East             S1384
# 7      38         East             S0174
# 8      47         East             S1435
# 9      52         East             S1472
# 10     54         East             S0516
#
#                            EstablishmentName      BRCName  \
# 0           EASWARAMMA SAI GURUKOOL ACCADEMY     Duga Brc
# 1        NEW GARDEN BOARDING SCHOOL (SAJONG)     Duga Brc
# 2        SARASWATI SHISHU VIDHYALAYA, BUDANG     Duga Brc
# 3           SAWNEY GOVERNMENT PRIMARY SCHOOL     Duga Brc
# 4     UPPER PACHAK GOVERNMENT PRIMARY SCHOOL     Duga Brc
# 5      KAMERAY GOVERNMENT PRIMARY SCHOOL (E)     Duga Brc
# 6                        NEW HORIZON ACADEMY     Duga Brc
# 7   UPPER LINGCHEY GOVERNMENT PRIMARY SCHOOL     Duga Brc
# 8          NEW VISION ACADEMY, CHOTA SINGTAM  Gangtok Brc
# 9                         TENDER BUDS SCHOOL  Gangtok Brc
# 10       10TH MILE GOVERNMENT PRIMARY SCHOOL  Gangtok Brc
#
#                                               CRCName SchoolLevel  \
# 0   Central Pendam Government Senior Secondary School          PS
# 1   Central Pendam Government Senior Secondary School          PS
# 2   Central Pendam Government Senior Secondary School          PS
# 3   Central Pendam Government Senior Secondary School          PS
# 4   Central Pendam Government Senior Secondary School          PS
# 5                  Rangpo Government Secondary School          PS
# 6                  Rangpo Government Secondary School          PS
# 7           Sumin Lingzey Government Secondary School          PS
# 8    Assam Lingzey Government Senior Secondary School          PS
# 9    Assam Lingzey Government Senior Secondary School          PS
# 10          Enchey Government Senior Secondary School          PS
#
#        ManagementName   LocalityHabitation SubdivisionName  ...  \
# 0   Private (Unaided)               RALUNG         Gangtok  ...
# 1   Private (Unaided)       CENTRAL PENDAM         Gangtok  ...
# 2   Private (Unaided)       CENTRAL PENDAM         Gangtok  ...
# 3         State Govt.               SAWNEY         Gangtok  ...
# 4         State Govt.         UPPER PACHAK         Gangtok  ...
# 5         State Govt.          EAST PENDAM         Pakyong  ...
# 6   Private (Unaided)                I.B.M         Gangtok  ...
# 7         State Govt.       UPPER LINGCHEY         Gangtok  ...
# 8   Private (Unaided)        CHOTA SINGTAM         Pakyong  ...
# 9   Private (Unaided)         ASSAMLINGZEY         Pakyong  ...
# 10        State Govt.  10TH MILE KARPONANG         Gangtok  ...
#
#                            EstablishmentName IsLibraryAvailable  \
# 0           EASWARAMMA SAI GURUKOOL ACCADEMY      Not Available
# 1        NEW GARDEN BOARDING SCHOOL (SAJONG)      Not Available
# 2        SARASWATI SHISHU VIDHYALAYA, BUDANG      Not Available
# 3           SAWNEY GOVERNMENT PRIMARY SCHOOL      Not Available
# 4     UPPER PACHAK GOVERNMENT PRIMARY SCHOOL      Not Available
# 5      KAMERAY GOVERNMENT PRIMARY SCHOOL (E)      Not Available
# 6                        NEW HORIZON ACADEMY      Not Available
# 7   UPPER LINGCHEY GOVERNMENT PRIMARY SCHOOL      Not Available
# 8          NEW VISION ACADEMY, CHOTA SINGTAM      Not Available
# 9                         TENDER BUDS SCHOOL      Not Available
# 10       10TH MILE GOVERNMENT PRIMARY SCHOOL      Not Available
#
#    AvailableBooksCount IsFireExtgAvailable ExtinguisherCount HOIRoomAvailable  \
# 0                    0           Available                 2        Available
# 1                    0       Not Available                 0    Not Available
# 2                    0       Not Available                 0    Not Available
# 3                    0           Available                 1        Available
# 4                    0           Available                 1    Not Available
# 5                    0           Available                 2    Not Available
# 6                    0           Available                 1        Available
# 7                    0           Available                 2        Available
# 8                    0       Not Available                 0        Available
# 9                    0       Not Available                 0        Available
# 10                   0       Not Available                 0        Available
#
#    IsStaffRoomAvailable NoofStaffRoom IsLockerForStaffAvailable  \
# 0         Not Available             0             Not Available
# 1         Not Available             0             Not Available
# 2             Available             1             Not Available
# 3             Available             1             Not Available
# 4             Available             1             Not Available
# 5             Available             1                 Available
# 6         Not Available             0             Not Available
# 7         Not Available             0             Not Available
# 8             Available             1             Not Available
# 9             Available             1             Not Available
# 10            Available             1             Not Available
#
#    IsSportsStoreRoomAvailable
# 0               Not Available
# 1                   Available
# 2               Not Available
# 3               Not Available
# 4               Not Available
# 5               Not Available
# 6                   Available
# 7               Not Available
# 8               Not Available
# 9               Not Available
# 10              Not Available
#
# [11 rows x 43 columns]

# %%
sql6 = """
SELECT * 
FROM school_details LEFT JOIN school_facility_details 
ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
WHERE school_details.SchoolLevel = "PS" AND school_facility_details.[IsLibraryAvailable] = "Not Available"
ORDER BY school_details.EstablishmentName
"""
returndata(sql6)
# Out:
# 2022-01-17 07:44:39,819 INFO sqlalchemy.engine.Engine
# SELECT AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
# FROM school_details
#
# 2022-01-17 07:44:39,819 INFO sqlalchemy.engine.Engine [raw sql] ()
#    avg_bac_distance
# 0         12.681822
#
#
# 2022-01-17 07:44:39,822 INFO sqlalchemy.engine.Engine
# SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
# FROM school_details
# GROUP BY school_details.SchoolLevel
#
# 2022-01-17 07:44:39,823 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0        None               NaN
# 1         JHS         13.692647
# 2         LPS          5.368421
# 3          PS         12.830787
# 4          SS         12.630872
# 5         SSS         10.863095
#
#
# 2022-01-17 07:44:39,826 INFO sqlalchemy.engine.Engine
# SELECT school_details.SchoolLevel, AVG(school_details.[BACDistance (in Km)]) AS avg_bac_distance
# FROM school_details
# GROUP BY school_details.SchoolLevel
# HAVING AVG(school_details.[BACDistance (in Km)]) >= 10
#
# 2022-01-17 07:44:39,826 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel  avg_bac_distance
# 0         JHS         13.692647
# 1          PS         12.830787
# 2          SS         12.630872
# 3         SSS         10.863095
#
#
# 2022-01-17 07:44:39,831 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details LEFT JOIN school_facility_details
# ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
# LIMIT 2
#
# 2022-01-17 07:44:39,831 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName  ...  \
# 0    State Govt.             BUDANG         Gangtok  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok  ...
#
#                                    EstablishmentName IsLibraryAvailable  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)          Available
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL          Available
#
#   AvailableBooksCount IsFireExtgAvailable ExtinguisherCount HOIRoomAvailable  \
# 0                 100           Available                 2        Available
# 1                   0           Available                 5        Available
#
#   IsStaffRoomAvailable NoofStaffRoom IsLockerForStaffAvailable  \
# 0            Available             1             Not Available
# 1            Available             2             Not Available
#
#   IsSportsStoreRoomAvailable
# 0              Not Available
# 1                  Available
#
# [2 rows x 43 columns]
#
#
# 2022-01-17 07:44:39,841 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details LEFT JOIN school_facility_details
# ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
# WHERE school_details.SchoolLevel = "PS" AND school_facility_details.[IsLibraryAvailable] = "Not Available"
#
# 2022-01-17 07:44:39,841 INFO sqlalchemy.engine.Engine [raw sql] ()
#     index DistrictName EstablishmentCode  \
# 0       5         East             S0856
# 1       8         East             S0876
# 2      15         East             S1230
# 3      16         East             S0768
# 4      20         East             S0131
# 5      24         East             S0245
# 6      28         East             S1384
# 7      38         East             S0174
# 8      47         East             S1435
# 9      52         East             S1472
# 10     54         East             S0516
#
#                            EstablishmentName      BRCName  \
# 0           EASWARAMMA SAI GURUKOOL ACCADEMY     Duga Brc
# 1        NEW GARDEN BOARDING SCHOOL (SAJONG)     Duga Brc
# 2        SARASWATI SHISHU VIDHYALAYA, BUDANG     Duga Brc
# 3           SAWNEY GOVERNMENT PRIMARY SCHOOL     Duga Brc
# 4     UPPER PACHAK GOVERNMENT PRIMARY SCHOOL     Duga Brc
# 5      KAMERAY GOVERNMENT PRIMARY SCHOOL (E)     Duga Brc
# 6                        NEW HORIZON ACADEMY     Duga Brc
# 7   UPPER LINGCHEY GOVERNMENT PRIMARY SCHOOL     Duga Brc
# 8          NEW VISION ACADEMY, CHOTA SINGTAM  Gangtok Brc
# 9                         TENDER BUDS SCHOOL  Gangtok Brc
# 10       10TH MILE GOVERNMENT PRIMARY SCHOOL  Gangtok Brc
#
#                                               CRCName SchoolLevel  \
# 0   Central Pendam Government Senior Secondary School          PS
# 1   Central Pendam Government Senior Secondary School          PS
# 2   Central Pendam Government Senior Secondary School          PS
# 3   Central Pendam Government Senior Secondary School          PS
# 4   Central Pendam Government Senior Secondary School          PS
# 5                  Rangpo Government Secondary School          PS
# 6                  Rangpo Government Secondary School          PS
# 7           Sumin Lingzey Government Secondary School          PS
# 8    Assam Lingzey Government Senior Secondary School          PS
# 9    Assam Lingzey Government Senior Secondary School          PS
# 10          Enchey Government Senior Secondary School          PS
#
#        ManagementName   LocalityHabitation SubdivisionName  ...  \
# 0   Private (Unaided)               RALUNG         Gangtok  ...
# 1   Private (Unaided)       CENTRAL PENDAM         Gangtok  ...
# 2   Private (Unaided)       CENTRAL PENDAM         Gangtok  ...
# 3         State Govt.               SAWNEY         Gangtok  ...
# 4         State Govt.         UPPER PACHAK         Gangtok  ...
# 5         State Govt.          EAST PENDAM         Pakyong  ...
# 6   Private (Unaided)                I.B.M         Gangtok  ...
# 7         State Govt.       UPPER LINGCHEY         Gangtok  ...
# 8   Private (Unaided)        CHOTA SINGTAM         Pakyong  ...
# 9   Private (Unaided)         ASSAMLINGZEY         Pakyong  ...
# 10        State Govt.  10TH MILE KARPONANG         Gangtok  ...
#
#                            EstablishmentName IsLibraryAvailable  \
# 0           EASWARAMMA SAI GURUKOOL ACCADEMY      Not Available
# 1        NEW GARDEN BOARDING SCHOOL (SAJONG)      Not Available
# 2        SARASWATI SHISHU VIDHYALAYA, BUDANG      Not Available
# 3           SAWNEY GOVERNMENT PRIMARY SCHOOL      Not Available
# 4     UPPER PACHAK GOVERNMENT PRIMARY SCHOOL      Not Available
# 5      KAMERAY GOVERNMENT PRIMARY SCHOOL (E)      Not Available
# 6                        NEW HORIZON ACADEMY      Not Available
# 7   UPPER LINGCHEY GOVERNMENT PRIMARY SCHOOL      Not Available
# 8          NEW VISION ACADEMY, CHOTA SINGTAM      Not Available
# 9                         TENDER BUDS SCHOOL      Not Available
# 10       10TH MILE GOVERNMENT PRIMARY SCHOOL      Not Available
#
#    AvailableBooksCount IsFireExtgAvailable ExtinguisherCount HOIRoomAvailable  \
# 0                    0           Available                 2        Available
# 1                    0       Not Available                 0    Not Available
# 2                    0       Not Available                 0    Not Available
# 3                    0           Available                 1        Available
# 4                    0           Available                 1    Not Available
# 5                    0           Available                 2    Not Available
# 6                    0           Available                 1        Available
# 7                    0           Available                 2        Available
# 8                    0       Not Available                 0        Available
# 9                    0       Not Available                 0        Available
# 10                   0       Not Available                 0        Available
#
#    IsStaffRoomAvailable NoofStaffRoom IsLockerForStaffAvailable  \
# 0         Not Available             0             Not Available
# 1         Not Available             0             Not Available
# 2             Available             1             Not Available
# 3             Available             1             Not Available
# 4             Available             1             Not Available
# 5             Available             1                 Available
# 6         Not Available             0             Not Available
# 7         Not Available             0             Not Available
# 8             Available             1             Not Available
# 9             Available             1             Not Available
# 10            Available             1             Not Available
#
#    IsSportsStoreRoomAvailable
# 0               Not Available
# 1                   Available
# 2               Not Available
# 3               Not Available
# 4               Not Available
# 5               Not Available
# 6                   Available
# 7               Not Available
# 8               Not Available
# 9               Not Available
# 10              Not Available
#
# [11 rows x 43 columns]
#
#
# 2022-01-17 07:44:39,858 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details LEFT JOIN school_facility_details
# ON school_details.EstablishmentCode = school_facility_details.EstablishmentCode
# WHERE school_details.SchoolLevel = "PS" AND school_facility_details.[IsLibraryAvailable] = "Not Available"
# ORDER BY school_details.EstablishmentName
#
# 2022-01-17 07:44:39,859 INFO sqlalchemy.engine.Engine [raw sql] ()
#     index DistrictName EstablishmentCode  \
# 0    1219         West             S1034
# 1      54         East             S0516
# 2     816        South             S0692
# 3    1102         West             S0374
# 4     209         East             S0108
# 5     832        South             S0415
# 6     817        South             S0646
# 7     916         West             S0529
# 8     939         West             S0557
# 9     691        South             S0682
# 10   1052         West             S1228
#
#                                     EstablishmentName        BRCName  \
# 0   (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...     Yuksom Brc
# 1                 10TH MILE GOVERNMENT PRIMARY SCHOOL    Gangtok Brc
# 2                   AAPGAZI GOVERNMENT PRIMARY SCHOOL       Temi Brc
# 3                 AARUBOTEY GOVERNMENT PRIMARY SCHOOL     Soreng Brc
# 4               AHO-YANGTAM GOVERNMENT PRIMARY SCHOOL    Pakyong Brc
# 5                  AIFALTAR GOVERNMENT PRIMARY SCHOOL       Temi Brc
# 6                    AMALAY GOVERNMENT PRIMARY SCHOOL       Temi Brc
# 7                   AMBOTEY GOVERNMENT PRIMARY SCHOOL   Daramdin Brc
# 8                     ANDEN GOVERNMENT PRIMARY SCHOOL   Daramdin Brc
# 9                  ANITHANG GOVERNMENT PRIMARY SCHOOL   Ravangla Brc
# 10                ANNES HOUSE ENGLISH SCHOOL, PELLING  Gyalshing Brc
#
#                                         CRCName SchoolLevel  \
# 0             Melli Government Secondary School          PS
# 1     Enchey Government Senior Secondary School          PS
# 2        Namphing Government Junior High School          PS
# 3          Chumbong Government Secondary School          PS
# 4        Aho-Shanti Government Secondary School          PS
# 5       Temi Government Senior Secondary School          PS
# 6        Namphing Government Junior High School          PS
# 7   Daramdin Government senior Secondary School          PS
# 8   Sombaria Government Senior Secondary School          PS
# 9           Jarrong Government Secondary School          PS
# 10   Pelling Government Senior Secondary School          PS
#
#        ManagementName      LocalityHabitation SubdivisionName  ...  \
# 0   Private (Unaided)  RIMBI/ SINGLITAM BUSTY       Gyalshing  ...
# 1         State Govt.     10TH MILE KARPONANG         Gangtok  ...
# 2         State Govt.                 AAPGAZI          Namchi  ...
# 3         State Govt.               AARUBOTEY          Soreng  ...
# 4         State Govt.             AHO-YANGTAM         Pakyong  ...
# 5         State Govt.                AIFALTAR        Ravangla  ...
# 6         State Govt.                  AMALAY          Namchi  ...
# 7         State Govt.                 AMBOTEY          Soreng  ...
# 8         State Govt.                   ANDEN          Soreng  ...
# 9         State Govt.                ANITHANG        Ravangla  ...
# 10  Private (Unaided)                 PELLING       Gyalshing  ...
#
#                                     EstablishmentName IsLibraryAvailable  \
# 0   (I.E.C) INDIAN EVANGALISTIC CRUSADE MISSION PR...      Not Available
# 1                 10TH MILE GOVERNMENT PRIMARY SCHOOL      Not Available
# 2                   AAPGAZI GOVERNMENT PRIMARY SCHOOL      Not Available
# 3                 AARUBOTEY GOVERNMENT PRIMARY SCHOOL      Not Available
# 4               AHO-YANGTAM GOVERNMENT PRIMARY SCHOOL      Not Available
# 5                  AIFALTAR GOVERNMENT PRIMARY SCHOOL      Not Available
# 6                    AMALAY GOVERNMENT PRIMARY SCHOOL      Not Available
# 7                   AMBOTEY GOVERNMENT PRIMARY SCHOOL      Not Available
# 8                     ANDEN GOVERNMENT PRIMARY SCHOOL      Not Available
# 9                  ANITHANG GOVERNMENT PRIMARY SCHOOL      Not Available
# 10                ANNES HOUSE ENGLISH SCHOOL, PELLING      Not Available
#
#    AvailableBooksCount IsFireExtgAvailable ExtinguisherCount HOIRoomAvailable  \
# 0                    0           Available                 1        Available
# 1                    0       Not Available                 0        Available
# 2                    0       Not Available                 0    Not Available
# 3                    0           Available                 2    Not Available
# 4                    0           Available                 2        Available
# 5                    0       Not Available                 0        Available
# 6                    0           Available                 2    Not Available
# 7                    0           Available                 2        Available
# 8                    0           Available                 2        Available
# 9                    0           Available                 2    Not Available
# 10                   0       Not Available                 0    Not Available
#
#    IsStaffRoomAvailable NoofStaffRoom IsLockerForStaffAvailable  \
# 0         Not Available             0             Not Available
# 1             Available             1             Not Available
# 2         Not Available             0             Not Available
# 3         Not Available             0             Not Available
# 4             Available             1             Not Available
# 5             Available             1             Not Available
# 6             Available             1             Not Available
# 7         Not Available             0             Not Available
# 8             Available             1             Not Available
# 9         Not Available             0             Not Available
# 10        Not Available             0             Not Available
#
#    IsSportsStoreRoomAvailable
# 0               Not Available
# 1               Not Available
# 2               Not Available
# 3               Not Available
# 4               Not Available
# 5               Not Available
# 6                   Available
# 7               Not Available
# 8               Not Available
# 9               Not Available
# 10              Not Available
#
# [11 rows x 43 columns]
