# %% [markdown]
# #Loading and Filtering Data Assignment
# ##Completed by Michael Akinosho
# ###Completed on 10/24/2021

# %%
import pandas as pd

# %%
filename = "/content/drive/Othercomputers/My Laptop/data-science-assignments/02 - Manipulating Data/RailsToTrails_National Count Data_week.xlsx"

# %%
df = pd.read_excel(filename)
df.head()
# Out:
#   Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 0    Week 1 2020-12-30  ...         NaN         NaN
# 1    Week 2 2020-01-06  ...         NaN         NaN
# 2    Week 3 2020-01-13  ...         NaN         NaN
# 3    Week 4 2020-01-20  ...         NaN         NaN
# 4    Week 5 2020-01-27  ...         NaN         NaN
#
# [5 rows x 10 columns]

# %%
df.shape
# Out:
# (52, 10)

# %% [markdown]
# #1. Selecting just the data after July 31, 2020

# %%
###Create filter to select rows using column Week of
###Filtering for rows after July 31st, 2020
week_of_filter = df['Week of'] > '2020-07-31'
df.loc[week_of_filter,:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 0 to 51
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   22 non-null     object
#  1   Week of                     22 non-null     datetime64[ns]
#  2    2019 counts (31 counters)  22 non-null     int64
#  3    2020 counts (31 counters)  22 non-null     int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            22 non-null     float64
#  6   Unnamed: 6                  22 non-null     float64
#  7   Unnamed: 7                  0 non-null      float64
#  8   Unnamed: 8                  1 non-null      float64
#  9   Unnamed: 9                  1 non-null      float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 1.9+ KB

# %% [markdown]
# #2. Selecting just the data from column 'Change 2019-2020' that is greater than 100%

# %%
###Create filter to select rows using column Change 2019-2020
###Filtering for rows with percentage greater than 100%
percent_cutoff_filter = df['Change 2019-2020'] > 1.0
df.loc[percent_cutoff_filter,:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 7 to 14
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   5 non-null      object
#  1   Week of                     5 non-null      datetime64[ns]
#  2    2019 counts (31 counters)  5 non-null      int64
#  3    2020 counts (31 counters)  5 non-null      int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            5 non-null      float64
#  6   Unnamed: 6                  5 non-null      float64
#  7   Unnamed: 7                  0 non-null      float64
#  8   Unnamed: 8                  0 non-null      float64
#  9   Unnamed: 9                  0 non-null      float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 440.0+ bytes

# %% [markdown]
# #First Checkpoint
# ###Adding this checkpoint to preserve the initial dataframe variable df

# %%
bikes_df1 = df

# %%
bikes_df1 = df.loc[week_of_filter & percent_cutoff_filter, :]

# %%
bikes_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   0 non-null      object
#  1   Week of                     0 non-null      datetime64[ns]
#  2    2019 counts (31 counters)  0 non-null      int64
#  3    2020 counts (31 counters)  0 non-null      int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            0 non-null      float64
#  6   Unnamed: 6                  0 non-null      float64
#  7   Unnamed: 7                  0 non-null      float64
#  8   Unnamed: 8                  0 non-null      float64
#  9   Unnamed: 9                  0 non-null      float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 0.0+ bytes

# %% [markdown]
# #3. Putting both week_of_filter and percent_cutoff_filter together results in zero rows; no rows meet both requirements.

# %%
#Checking after creating bikes_df1 that df variable has not changed
df.head()
# Out:
#   Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 0    Week 1 2020-12-30  ...         NaN         NaN
# 1    Week 2 2020-01-06  ...         NaN         NaN
# 2    Week 3 2020-01-13  ...         NaN         NaN
# 3    Week 4 2020-01-20  ...         NaN         NaN
# 4    Week 5 2020-01-27  ...         NaN         NaN
#
# [5 rows x 10 columns]
